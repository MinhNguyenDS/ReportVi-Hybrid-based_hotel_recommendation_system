# %%
import pandas as pd
import requests
import numpy as np

# %% [markdown]
# ## https://www.traveloka.com/

# %%
def df_for_traveloka(id = 0, address = '_', name = '_'):
  """
      id: id của khách sạn
      address: địa điểm của khách sạn
      name: tên của khách sạn
  """
  numbercmt = 50
  number = 0
  hotelId = str(id)
  Address = address
  NameHotel = name
  while number < numbercmt:
    url = 'https://www.traveloka.com/api/v2/hotel/getHotelReviews/'

    myobj = {"fields":[],"data":{"filterSortSpec":{"travelTheme":"","travelType":'',"sortType":"LANGUAGE","tagIds":[]},"hotelReviewFilterClientSpec":{"hasPhotos":"false"},"hotelReviewSortClientSpec":{"sortType":"LANGUAGE"},"ascending":"True","reviewLanguage":"VIETNAMESE","hotelId":hotelId,"skip":number,"top":50},"clientInterface":"desktop"}

    headers = {
      "Connection": "keep-alive",
      "Origin": "https://www.traveloka.com",
      "content-type": "application/json",
      "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
      "Accept": "/",
      "x-domain": "accomContent",
      "Cookie": 'tv-repeat-visit=true; tvs=; _gcl_au=1.1.2000255326.1670169608; _gid=GA1.2.1124838509.1670169609; _fbp=fb.1.1670169609118.765044241; g_state={"i_p":1670176826419,"i_l":1}; cto_bundle=1GTQ2V9kN2VBUTUwdGJyV3IzVHZ3MjhEQ3phT3dKc2ZFYm1BeW0lMkZ0TDNuTEJrUnJJcGtFMHlWTWN0QkZIMmVnYnRZN0MyMWNSUjR4ckExJTJCRlFlOTAlMkJOTU5pSkN4TkVtUkpocHNBS0NNR1JBJTJGc2RDeEJrYWRhRzd3RXQ5ajM5aDBaUUQ5dUtINkQyWW9QZSUyQmtRYlA2QVhjZkF3JTNEJTNE; amp_1a5adb=gYsOn2yUPs2qD6MSRfgLeA...1gjetrfr6.1gjeu1i2b.b.0.b; _ga=GA1.2.596011191.1670169608; _ga_RSRSMMBH0X=GS1.1.1670169608.1.1.1670169820.4.0.0; tvl=qgdHX7GvehrD9XH5a3S4PdE8AYpuF3hYPaT5bxhY7ZY66A23o/D0mBG9gAQyqubeUwYEchuByiChdRzJ63eSNv2hdUvXhLuW5Ds2dsfThOASrq6LtykzIoPb927mY3gCa3if7baItKFC7NCxk4M1HAnqzUr8RyIi/REmk++CebDvlyHfFnPptZUxAgMVwRNSCMYWUJplNNMY2P4/83O9X+8GNrPf8Ng75ZieUaJama8='
    }

    req_travel = requests.post(url, json = myobj, headers = headers)

    count = 0
    reviewerName = []
    overallScore = []
    reviewText = []
    for item in req_travel.json()['data']['reviewList']:
      count +=1
      if item['reviewText'] != None:
        reviewerName.append(item['reviewerName'])
        overallScore.append(item['overallScore'])
        reviewText.append(item['reviewText'])

    df_temp = pd.DataFrame({'reviewerName':reviewerName, 'Address': Address, 'NameHotel': NameHotel, 'overallScore':overallScore, 'reviewText':reviewText})
    if number == 0: df_travel = df_temp
    else: df_travel = pd.concat([df_travel, df_temp])

    numbercmt = int(req_travel.json()['data']['aggregateInfo']['numOfFullReviews'])
    if count < 50: numbercmt = number + count
    number += 50

  return df_travel

# %% [markdown]
# ### Id và tên khách sạn từng địa điểm

# %% [markdown]
# #### Đà Nẵng

# %%
# Đà Nẵng
list_ht = [[3000010025979, "Khu nghỉ dưỡng Risemount Premier Đà Nẵng"]]

list_ht_new = [[9000000134494, "Davue Hotel Da Nang"],
               [1000000539426, "Le House Boutique Hotel"],
               [3000020001392, "La Beach Hotel"],
               [3000020011770, "Seashore Hotel & Apartment "],
               [3000010029603, "Alibaba Hotel Da Nang"],
               [3000010032247, "Khách sạn Zalo Sea"],
               [1000000441652, "Muong Thanh Grand Da Nang Hotel"],
               [3000020020275, "King House Villa Hotel & Spa"],
               [1000000537311, "Mercure Danang French Village Bana Hills"],
               [3000020017372, "The Secret Garden Hostel"],
[1000000397928, "Khu nghỉ dưỡng và Spa Mikazuki Nhật Bản"],
[9000000987449, "Menora Grand Đà Nẵng"],
[9000000309699, "GIC Luxury Hotel And Spa"],
[1000000490040, "Angel Hotel Danang"],
[3000010040062, "Khách sạn Royal Charm"],
[1000000453412, "Khách sạn Brown Bean"],
[9000000434672, "The Garden Hotel and Apartment"],
[3000010030733, "Lotus Rock Hotel"]]

# %%
for i in range(len(list_ht)):
  df_temp0 = df_for_traveloka(list_ht[i][0], "Đà Nẵng", list_ht[i][1])

  if i == 0: df_new = df_temp0
  else: df_new = pd.concat([df_new, df_temp0])

for i in range(len(list_ht_new)):
  df_temp0 = df_for_traveloka(list_ht_new[i][0], "Đà Nẵng", list_ht_new[i][1])
  df_under = df_temp0[df_temp0.overallScore.astype("float") < 8]
  df_up = df_temp0[df_temp0.overallScore.astype("float") >= 8][:len(df_under)]

  df_new = pd.concat([df_new, df_up, df_under])

df_new['overallScore'] = df_new['overallScore'].astype(np.float64)
df_new.to_csv('df_travel_DaNang.csv', index=False, header=True)

# %% [markdown]
# #### Nha Trang

# %%
# Nha Trang
list_ht = [[1000000192322, 'Vinpearl Resort Nha Trang - Hon Tre Island']]

list_ht_new = [[3000020017982, 'Muong Thanh Luxury Khanh Hoa Hotel'],
               [3000020002678, 'Melissa Hotel Nha Trang'],
               [1000000482039, 'Mường Thanh Luxury Nha Trang'],
               [1000000430754, 'Khách sạn Sun City Nha Trang'],
               [9000000494790, 'Holi Panorama Nha Trang'],
               [1000000515132, 'Rex Hotel and Apartment'],
               [3000010021134, 'Gold Ocean Apartments Nha Trang'],
               [3000020009806, 'V Hotel Nha Trang'],
               [3000020004247, 'Smile Hotel Nha Trang'],
               [1000000432590, 'Premier Havana Nha Trang Hotel'],
[3000020017982, 'Khách sạn Mường Thanh Luxury Khánh Hòa'],
[9000000928831, 'La Vague Hotel Nha Trang'],
[1000000600597, 'Aroma Nha Trang Boutique Hotel'],
[3000010023795, 'Khách sạn Senkotel Nha Trang'],
[1000000392557, 'Le Soleil Nha Trang Hotel'],
[1000000476044, 'Khách sạn Modern Sky Nha Trang']]

# %%
for i in range(len(list_ht)):
  df_temp0 = df_for_traveloka(list_ht[i][0], "Nha Trang", list_ht[i][1])

  if i == 0: df_new = df_temp0
  else: df_new = pd.concat([df_new, df_temp0])

for i in range(len(list_ht_new)):
  df_temp0 = df_for_traveloka(list_ht_new[i][0], "Nha Trang", list_ht_new[i][1])
  df_under = df_temp0[df_temp0.overallScore.astype("float") < 8]
  df_up = df_temp0[df_temp0.overallScore.astype("float") >= 8][:len(df_under)]

  df_new = pd.concat([df_new, df_up, df_under])

df_new['overallScore'] = df_new['overallScore'].astype(np.float64)
df_new.to_csv('df_travel_NhaTrang.csv', index=False, header=True)

# %% [markdown]
# #### Phú Quốc

# %%
#Phú Quốc:
list_ht = [[3000020012744, 'VinOasis Phu Quoc']]

list_ht_new = [[3000020012744, 'Wyndham Grand Phu Quoc'],
               [3000020000089, 'Lahana Resort Phú Quốc & Spa'],
               [1000000458625, 'The Shells Resort & Spa Phú Quốc'],
               [1000000429338, 'Famiana Resort & Spa Phú Quốc'],
               [3000020017782, 'Radisson Blu Resort Phu Quoc'],
               [3000020021019, 'VARIA Hotel'],
               [3000010030791, 'Mường Thanh Luxury Phú Quốc Hotel'],
               [1000000594716, 'Blue Sky Phú Quốc Hotel'],
               [3000010043411, 'Seashells Phu Quoc Hotel & Spa'],
               [1000000573747, 'Halona Hotel Phu Quoc'],
               [1000000425916, 'Arcadia Phu Quoc Resort'],
[3000020008174, 'The Palmy Phú Quốc Resort & Spa'],
[9000000890249, 'Vinholidays Fiesta Phú Quốc'],
[9000000927704, 'The May Hotel Phu Quoc'],
[3000010027654, 'Venus Hotel & Sky Bar Phu Quoc'],
[3000020016636, 'S Bungalow Phu Quoc'],
[9000000020384, 'Linh Dan Bungalow']]

# %%
for i in range(len(list_ht)):
  df_temp0 = df_for_traveloka(list_ht[i][0], "Phú Quốc", list_ht[i][1])

  if i == 0: df_new = df_temp0
  else: df_new = pd.concat([df_new, df_temp0])

for i in range(len(list_ht_new)):
  df_temp0 = df_for_traveloka(list_ht_new[i][0], "Phú Quốc", list_ht_new[i][1])
  df_under = df_temp0[df_temp0.overallScore.astype("float") < 8]
  df_up = df_temp0[df_temp0.overallScore.astype("float") >= 8][:len(df_under)]

  df_new = pd.concat([df_new, df_up, df_under])

df_new['overallScore'] = df_new['overallScore'].astype(np.float64)
df_new.to_csv('df_travel_PhuQuoc.csv', index=False, header=True)

# %% [markdown]
# #### Vũng Tàu

# %%
#Vũng Tàu:
list_ht = [[3000020015542, 'Melia Ho Tram Beach Resort']]

list_ht_new = [[9000001071485, 'Milan Homestay - The Song Vung Tau'],
               [9000000961953, 'Premier Pearl Hotel Vung Tau'],
               [1000000324420, 'Khách sạn Imperial Vũng Tàu'],
               [9000001136478, 'Song Homestay - The Song Vung Tau'],
               [9000000882550, 'The Cap Hotel'],
               [9000000134037, 'Annata Beach Hotel'],
               [9000000730242, 'Fusion Suites Vung Tau'],
               [1000001599108, 'Bella VT Hotel'],
               [3000020004772, 'Lan Rung Phuoc Hai Resort & Spa'],
               [9000000095074, 'Khách sạn Riva Vũng Tàu'],
               [3000020020369, 'Nolis Hotel Vung Tau'],
               [1000000421574, 'Seaside Resort Vung Tau'],
[3000020002160, 'Oceanami Villas & Beach Club'],
[3000020017765, 'Vietsovpetro Resort'],
[1000000473658, 'Minera Hot Springs Binh Chau'],
[1000000543702, 'Khách sạn Royal Vũng Tàu'],
[3000020007238, 'Khách sạn San Hô Vũng Tàu'],
[3000020020189, 'VND Hotel'],
[3000010023792, 'Khách sạn Tháng Mười'],
[3000010031099, 'Khách sạn Hoàng Yến']]

# %%
for i in range(len(list_ht)):
  df_temp0 = df_for_traveloka(list_ht[i][0], "Vũng Tàu", list_ht[i][1])

  if i == 0: df_new = df_temp0
  else: df_new = pd.concat([df_new, df_temp0])

for i in range(len(list_ht_new)):
  df_temp0 = df_for_traveloka(list_ht_new[i][0], "Vũng Tàu", list_ht_new[i][1])
  df_under = df_temp0[df_temp0.overallScore.astype("float") < 8]
  df_up = df_temp0[df_temp0.overallScore.astype("float") >= 8][:len(df_under)]

  df_new = pd.concat([df_new, df_up, df_under])

df_new['overallScore'] = df_new['overallScore'].astype(np.float64)
df_new.to_csv('df_travel_VungTau.csv', index=False, header=True)

# %% [markdown]
# #### Hà Nội

# %%
#Hà Nội:
list_ht = [[1000000471110, 'Khách sạn Lotte Hà Nội']]

list_ht_new = [[1000000399730, 'Classy Boutique Hotel'],
               [1000000362205, 'Hanoi De Maison Grand Hotel'],
               [1000001037181, 'Millennium Hanoi Hotel'],
               [9000001072104, 'Ha Noi Le Grand Hotel'],
               [9000000092445, 'Hanoi Gatsby Hotel'],
               [1000000514492, 'Khách sạn Marriotte Hà Nội'],
               [9000000969729, 'Hanoi Boutique Hotel'],
               [1000000468475, 'Khách sạn Hanoi Sunshine'],
               [1000000404028, 'King Ly Hotel'],
               [3000010024814, 'V-Studio Hotel Apartment 2'],
[1000000552381, 'MK Premier Boutique Hotel'],
[3000020012911, 'Dal Vostro Hotel & Spa'],
[1000000468475, 'Khách sạn Hanoi Sunshine'],
[3000010024132, 'Ma Coeur Boutique Hotel'],
[9000000297534, 'Green Hotel & Apartment HN'],
[3000020017936, 'Thang Long Hotel Hanoi'],
[1000000406897, 'Hanoi Charming House'],
[9000000889994, 'New Style House Hotel']]

# %%
for i in range(len(list_ht)):
  df_temp0 = df_for_traveloka(list_ht[i][0], "Hà Nội", list_ht[i][1])

  if i == 0: df_new = df_temp0
  else: df_new = pd.concat([df_new, df_temp0])

for i in range(len(list_ht_new)):
  df_temp0 = df_for_traveloka(list_ht_new[i][0], "Hà Nội", list_ht_new[i][1])
  df_under = df_temp0[df_temp0.overallScore.astype("float") < 8]
  df_up = df_temp0[df_temp0.overallScore.astype("float") >= 8][:len(df_under)]

  df_new = pd.concat([df_new, df_up, df_under])

df_new['overallScore'] = df_new['overallScore'].astype(np.float64)
df_new.to_csv('df_travel_HaNoi.csv', index=False, header=True)

# %% [markdown]
# #### Đà Lạt

# %%
#Đà Lạt:
list_ht = [[1000000384092, 'Dalat Edensee Lake Resort & Spa']]

list_ht_new = [[3000010042556, 'The Grace Hotel Dalat'],
               [1000000490882, 'Terracotta Hotel & Resort Đà Lạt'],
               [9000000817630, 'Pontus Hotel'],
               [3000020016442, 'Vuong Gia Hotel'],
               [3000020010764, 'The Luxe Hotel'],
               [3000020014998, 'Hôtel Colline Dalat'],
               [9000000966496, 'Hưng Nguyên Valley Đà Lạt'],
               [3000020015784, 'Larita Da Lat Boutique Hotel'],
               [3000010034696, 'Nam Xuan Premium Hotel'],
               [3000020012481, 'Dalat Home Villa'],
               [3000020015279, 'Dalat Wonder Resort'],
               [1000000561614, 'Swiss-Belresort Tuyen Lam Dalat'],
[1000000325613, 'Ana Mandara Villas Dalat Resort & Spa'],
[3000020018813, 'Cereja Hotel & Resort Dalat'],
[1000000443207, 'Vietsovpetro Dalat Hotel'],
[9000000975119, 'K Boutique Hotel in Dalat'],
[1000000529713, 'Royal Dalat Hotel'],
[1000001765514, 'Victorian Hotel Dalat'],
[3000010026362, 'Khách sạn Hồng Tâm Đà Lạt'],
[3000010026827, 'Khách sạn Phương Uyên Đà Lạt']]

# %%
for i in range(len(list_ht)):
  df_temp0 = df_for_traveloka(list_ht[i][0], "Đà Lạt", list_ht[i][1])

  if i == 0: df_new = df_temp0
  else: df_new = pd.concat([df_new, df_temp0])

for i in range(len(list_ht_new)):
  df_temp0 = df_for_traveloka(list_ht_new[i][0], "Đà Lạt", list_ht_new[i][1])
  df_under = df_temp0[df_temp0.overallScore.astype("float") < 8]
  df_up = df_temp0[df_temp0.overallScore.astype("float") >= 8][:len(df_under)]

  df_new = pd.concat([df_new, df_up, df_under])

df_new['overallScore'] = df_new['overallScore'].astype(np.float64)
df_new.to_csv('df_travel_DaLat.csv', index=False, header=True)

# %% [markdown]
# #### Hội An

# %%
#Hội An:
list_ht = [[9000000337325, 'Anio Boutique Hotel Hoi An']]

list_ht_new= [[9000000133984, 'The Nam An Villa Hoi An'],
              [1000000492057, 'Khách sạn Mường Thanh Holiday Hội An'],
              [3000010034587, 'Hoi An Canal House '],
              [1000000628529, 'Lasenta Boutique Hotel Hoian'],
              [1000000428349, 'Khách Sạn Hoài Niệm Hội An'],
              [1000000531603, 'Pho Hoi 1 Hotel'],
              [9000000000980, 'La An Central Boutique Villa'],
              [3000010032335, 'Hoi An Rose Garden Hotel'],
              [3000010030328, 'Fireworks Homestay'],
              [1000000603810, 'Golden Bell Backpacker Hotel & Pool Bar'],
[1000000628529, 'Lasenta Boutique Hotel Hoian'],
[1000000257265, 'Hoi An River Beach Resort and Residences'],
[3000010037105, 'TTC Hotel - Hoi An'],
[1000000510323, 'Golden River Hotel'],
[1000000380629, 'Thanh Binh Central Hotel'],
[1000000481032, 'Hội An Reverie Villas'],
[3000010032614, 'Khách sạn Thanh Bình 2'],
[3000010039953, 'Hội An Việt House Homestay']]

# %%
for i in range(len(list_ht)):
  df_temp0 = df_for_traveloka(list_ht[i][0], "Hội An", list_ht[i][1])

  if i == 0: df_new = df_temp0
  else: df_new = pd.concat([df_new, df_temp0])

for i in range(len(list_ht_new)):
  df_temp0 = df_for_traveloka(list_ht_new[i][0], "Hội An", list_ht_new[i][1])
  df_under = df_temp0[df_temp0.overallScore.astype("float") < 8]
  df_up = df_temp0[df_temp0.overallScore.astype("float") >= 8][:len(df_under)]

  df_new = pd.concat([df_new, df_up, df_under])

df_new['overallScore'] = df_new['overallScore'].astype(np.float64)
df_new.to_csv('df_travel_HoiAn.csv', index=False, header=True)

# %% [markdown]
# #### Phan Thiết

# %%
#Phan Thiết:
list_ht = [[1000000321549, 'Azerai Ke Ga Bay']]

list_ht_new = [[1000000438560, 'The Sailing Bay Beach Resort'],
               [3000010021795, 'Muong Thanh Holiday Mui Ne Hotel'],
               [3000010033386, 'Lotus Village Resort Mui Ne'],
               [1000000418189, 'The Cliff Resort & Residences'],
               [1000000412195, 'Muine Bay Resort'],
               [1000000359467, 'TTC Hotel Phan Thiết'],
               [1000000491765, 'Rạng Garden Beach Side Resort'],
               [1000000547430, 'Surf4You Residence'],
               [1000000487275, 'Sandunes Beach Resort and Spa'],
               [1000000447860, 'Khách sạn Minh Hùng'],
[1000000353191, 'Sea Links Beach Resort & Golf'],
[1000000185636, 'Phan Thiet Ocean Dunes Resort'],
[1000000427906, 'Resort Poshanu'],
[1000000491765, 'Rạng Garden Beach Side Resort'],
[3000010029791, 'Mũi Né Boutique Hotel'],
[1000000500458, 'Hai Yen Family Resort'],
[1000000503988, 'Nohana Hotel (Former Y Khoa Hotel)']]

# %%
for i in range(len(list_ht)):
  df_temp0 = df_for_traveloka(list_ht[i][0], "Phan Thiết", list_ht[i][1])

  if i == 0: df_new = df_temp0
  else: df_new = pd.concat([df_new, df_temp0])

for i in range(len(list_ht_new)):
  df_temp0 = df_for_traveloka(list_ht_new[i][0], "Phan Thiết", list_ht_new[i][1])
  df_under = df_temp0[df_temp0.overallScore.astype("float") < 8]
  df_up = df_temp0[df_temp0.overallScore.astype("float") >= 8][:len(df_under)]

  df_new = pd.concat([df_new, df_up, df_under])

df_new['overallScore'] = df_new['overallScore'].astype(np.float64)
df_new.to_csv('df_travel_PhanThiet.csv', index=False, header=True)

# %% [markdown]
# #### Quy Nhơn

# %%
#Quy Nhơn:
list_ht = [[1000000327221, 'AVANI Quy Nhon Resort and Spa']]

list_ht_new = [[3000010021262, 'FLC Luxury Resort Quy Nhon'],
               [1000000910037, 'Khách sạn Phương Đông'],
               [3000020020901, 'Mira Hotel'],
               [3000010025455, 'Muong Thanh Quy Nhon Hotel'],
               [1000000255828, 'Khách sạn Hải Âu Quy Nhơn'],
               [3000010031615, 'Ly Ky Hotel'],
               [3000020021078, 'Delight Hotel'],
               [9000000134682, 'Anya Hotel Quy Nhon'],
               [3000010043126, 'Blue Sea Hotel Quy Nhon'],
[9000000134682, 'Anya Hotel Quy Nhon'],
[3000020003490, 'Casa Marina Resort'],
[3000010029787, 'Khách sạn Hoàng Yến 1 Quy Nhơn'],
[3000020013159, 'O.Six Resort'],
[3000020020065, 'Mento Hotel Quy Nhon'],
[1000000561362, 'Hoang Yen Canary Hotel Quy Nhon'],
[3000010029798, 'Hong Diep Hotel Quy Nhon']]

# %%
for i in range(len(list_ht)):
  df_temp0 = df_for_traveloka(list_ht[i][0], "Quy Nhơn", list_ht[i][1])

  if i == 0: df_new = df_temp0
  else: df_new = pd.concat([df_new, df_temp0])

for i in range(len(list_ht_new)):
  df_temp0 = df_for_traveloka(list_ht_new[i][0], "Quy Nhơn", list_ht_new[i][1])
  df_under = df_temp0[df_temp0.overallScore.astype("float") < 8]
  df_up = df_temp0[df_temp0.overallScore.astype("float") >= 8][:len(df_under)]

  df_new = pd.concat([df_new, df_up, df_under])

df_new['overallScore'] = df_new['overallScore'].astype(np.float64)
df_new.to_csv('df_travel_QuyNhon.csv', index=False, header=True)

# %% [markdown]
# #### Huế

# %%
#Huế:
list_ht = [[3000020017508, 'Melia Vinpearl Hue']]

list_ht_new = [[1000000240823, 'Hương Giang Hotel Resort & Spa'],
               [1000000324575, 'Khách sạn Mường Thanh Holiday Huế'],
               [1000000622565, 'Hotel La Perle'],
               [1000000268904, 'Cherish Hotel Hue'],
               [9000000975111, 'Jade Scene Hotel'],
               [1000000615976, 'Flora Hotel Hue'],
               [3000020010460, 'Amona Hotel'],
               [1000000414845, 'Than Thien Friendly Hotel'],
               [1000000429469, 'Moonlight Hotel Hue'],
[1000000244101, 'Khu nghỉ dưỡng Pilgrimage Village Boutique'],
[1000000170888, 'Century Riverside Hue'],
[3000020015989, 'The Sunriver Boutique Hotel Hue'],
[1000000500440, 'Phong Nha Hotel Hue'],
[3000010036694, 'Khách sạn Poetic Huế'],
[1000000392926, 'Hong Thien 1 Hotel'],
[1000000424099, 'DMZ Hotel'],
[3000020001254, 'TinTin Hostel']]

# %%
for i in range(len(list_ht)):
  df_temp0 = df_for_traveloka(list_ht[i][0], "Huế", list_ht[i][1])

  if i == 0: df_new = df_temp0
  else: df_new = pd.concat([df_new, df_temp0])

for i in range(len(list_ht_new)):
  df_temp0 = df_for_traveloka(list_ht_new[i][0], "Huế", list_ht_new[i][1])
  df_under = df_temp0[df_temp0.overallScore.astype("float") < 8]
  df_up = df_temp0[df_temp0.overallScore.astype("float") >= 8][:len(df_under)]

  df_new = pd.concat([df_new, df_up, df_under])

df_new['overallScore'] = df_new['overallScore'].astype(np.float64)
df_new.to_csv('df_travel_Hue.csv', index=False, header=True)

# %% [markdown]
# #### TP.HCM

# %%
# #Hồ Chí Minh:
# list_ht = [[9000000876237, 'Khách sạn Mường Thanh Luxury Sài Gòn'],
# [3000010029727, 'Ruby Saigon Hotel'],
# [1000000583043, 'The Noble Swan Woodpark Hotel'],
# [1000000478378, 'Ky Hoa Hotel Saigon'],
# [9000000957471, 'Khách sạn Cozrum Smart - First Target'],
# [3000010029727, 'Ruby Saigon Hotel'],
# [1000000486576, 'Spring House Hotel'],
# [1000000568066, 'ACE Hotel Saigon'],
# [1000000374041, 'Khách sạn DDA Quận 1'],
# [3000010027042, 'Khách sạn Meraki Boutique']]

# %%
# for i in range(len(list_ht)):
#   df_temp0 = df_for_traveloka(list_ht[i][0], "Hồ Chí Minh", list_ht[i][1])

#   if i == 0: df_new = df_temp0
#   else: df_new = pd.concat([df_new, df_temp0])

# df_new['overallScore'] = df_new['overallScore'].astype(np.float64)

# df_new.to_csv('df_travel_HCM.csv', index=False, header=True)

# %% [markdown]
# #### Hạ Long

# %%
# #Hạ Long:
# list_ht = [[3000020019359, 'FLC Halong Bay Golf Club & Luxury Resort'],
# [1000000620395, 'Khách sạn Wyndham Legend Halong'],
# [1000000456656, 'Khách sạn Mường Thanh Luxury Quảng Ninh'],
# [1000000500018, 'Khách sạn Mường Thanh Grand Hạ Long'],
# [1000000266339, 'Saigon Halong Hotel'],
# [9000000883282, "Khách sạn D'Lecia Ha Long"],
# [1000000463947, 'City Bay Palace Hotel'],
# [3000020016689, 'Ivy Hotel - Ha Long'],
# [3000020015179, 'The Bay - Ha Long Homestay']]

# %%
# for i in range(len(list_ht)):
#   df_temp0 = df_for_traveloka(list_ht[i][0], "Hạ Long", list_ht[i][1])

#   if i == 0: df_new = df_temp0
#   else: df_new = pd.concat([df_new, df_temp0])

# df_new['overallScore'] = df_new['overallScore'].astype(np.float64)

# df_new.to_csv('df_travel_HaLong.csv', index=False, header=True)

# %% [markdown]
# ### Gộp các dataset của từng địa điểm

# %%
df_1 = pd.read_csv('df_travel_DaNang.csv')
df_2 = pd.read_csv('df_travel_NhaTrang.csv')
df_3 = pd.read_csv('df_travel_PhuQuoc.csv')
df_4 = pd.read_csv('df_travel_VungTau.csv')
# df_5 = pd.read_csv('df_travel_HaNoi.csv')
df_6 = pd.read_csv('df_travel_DaLat.csv')
df_7 = pd.read_csv('df_travel_HoiAn.csv')
df_8 = pd.read_csv('df_travel_PhanThiet.csv')
df_9 = pd.read_csv('df_travel_QuyNhon.csv')
df_10 = pd.read_csv('df_travel_Hue.csv')
# df_11 = pd.read_csv('df_travel_HCM.csv')
# df_12 = pd.read_csv('df_travel_HaLong.csv')

# %%
df_travel_total = pd.concat([df_1, df_2, df_3, df_4, df_6, df_7, df_8, df_9, df_10])
df_travel_total.drop_duplicates(inplace=True)
df_travel_total.columns=['CustomerName', 'Address', 'NameHotel', 'Ratting', 'Review']
df_travel_total = df_travel_total.drop_duplicates(subset='Review', keep='first')
df_travel_total = df_travel_total.sample(frac=1).reset_index(drop=True)

df_travel_total = df_travel_total[df_travel_total.Review.str.len() >= 10]
df_travel_total = df_travel_total[df_travel_total.Review.str.len() <= 500]
df_travel_total['Review'] = df_travel_total['Review'].str.replace('\n', ' ')

df_travel_total = df_travel_total.set_index(np.array(range(df_travel_total.shape[0])))

# %%
df_check = df_travel_total[df_travel_total.Review.str.len() >= 50]

# %%
df_travel_total.to_csv('df_travel_10K.csv', index=False, header=True)

# %% [markdown]
# ## Precess

# %%
df_travel_total
# Out:
#         CustomerName     Address                                   NameHotel  \
# 0      Thi T. T. T.       Hà Nội                  Green Hotel & Apartment HN
# 1        Tran Q. H.   Phan Thiết                 Lotus Village Resort Mui Ne
# 2       Luong Q. H.       Hà Nội                        Hanoi Charming House
# 3         Chi H. N.     Vũng Tàu            Terracotta Hotel & Resort Đà Lạt
# 4         The A. H.     Vũng Tàu                         Hôtel Colline Dalat
# ...              ...         ...                                         ...
# 10287  Van P. K. C.   Phan Thiết                            Muine Bay Resort
# 10288    Ngoc L. N.      Đà Nẵng  Khu nghỉ dưỡng và Spa Mikazuki Nhật Bản
# 10289     Thi N. N.   Phan Thiết            Muong Thanh Holiday Mui Ne Hotel
# 10290  Nguyen T. X.       Hội An                          TTC Hotel - Hoi An
# 10291  Thi K. N. N.    Nha Trang                Khách sạn Senkotel Nha Trang
#
# ...

# %%
df_total = pd.read_csv('df_travel_10K.csv')

# %%
df_total.dropna(inplace=True)

# %%
df_total = df_total.set_index(np.array(range(df_total.shape[0])))

# %%
import regex as re

uniChars = "àáảãạâầấẩẫậăằắẳẵặèéẻẽẹêềếểễệđìíỉĩịòóỏõọôồốổỗộơờớởỡợùúủũụưừứửữựỳýỷỹỵÀÁẢÃẠÂẦẤẨẪẬĂẰẮẲẴẶÈÉẺẼẸÊỀẾỂỄỆĐÌÍỈĨỊÒÓỎÕỌÔỒỐỔỖỘƠỜỚỞỠỢÙÚỦŨỤƯỪỨỬỮỰỲÝỶỸỴÂĂĐÔƠƯ"
unsignChars = "aaaaaaaaaaaaaaaaaeeeeeeeeeeediiiiiooooooooooooooooouuuuuuuuuuuyyyyyAAAAAAAAAAAAAAAAAEEEEEEEEEEEDIIIOOOOOOOOOOOOOOOOOOOUUUUUUUUUUUYYYYYAADOOU"


def loaddicchar():
    dic = {}
    char1252 = 'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ'.split(
        '|')
    charutf8 = "à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ".split(
        '|')
    for i in range(len(char1252)):
        dic[char1252[i]] = charutf8[i]
    return dic


dicchar = loaddicchar()

# Đưa toàn bộ dữ liệu qua hàm này để chuẩn hóa lại
def convert_unicode(txt):
    return re.sub(
        r'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ',
        lambda x: dicchar[x.group()], txt)

def no_accent_vietnamese(s):
    convert_unicode(s)
    s = re.sub(u'[àáạảãâầấậẩẫăằắặẳẵ]', 'a', s)
    s = re.sub(u'[ÀÁẠẢÃĂẰẮẶẲẴÂẦẤẬẨẪ]', 'A', s)
    s = re.sub(u'[èéẹẹẻẽêềếệểễ]', 'e', s)
    s = re.sub(u'[ÈÉẸẺẼÊỀẾỆỂỄ]', 'E', s)
    s = re.sub(u'[òóọỏõôồốộổỗơờớợởỡ]', 'o', s)
    s = re.sub(u'[ÒÓỌỎÕÔỒỐỘỔỖƠỜỚỢỞỠ]', 'O', s)
    s = re.sub(u'[ìíịỉĩ]', 'i', s)
    s = re.sub(u'[ÌÍỊỈĨ]', 'I', s)
    s = re.sub(u'[ùúụủũưừứựửữ]', 'u', s)
    s = re.sub(u'[ƯỪỨỰỬỮÙÚỤỦŨ]', 'U', s)
    s = re.sub(u'[ỳýỵỷỹ]', 'y', s)
    s = re.sub(u'[ỲÝỴỶỸ]', 'Y', s)
    s = re.sub(u'Đ', 'D', s)
    s = re.sub(u'đ', 'd', s)

    return s

# %%
bang_nguyen_am = [['a', 'à', 'á', 'ả', 'ã', 'ạ', 'a'],
                  ['ă', 'ằ', 'ắ', 'ẳ', 'ẵ', 'ặ', 'aw'],
                  ['â', 'ầ', 'ấ', 'ẩ', 'ẫ', 'ậ', 'aa'],
                  ['e', 'è', 'é', 'ẻ', 'ẽ', 'ẹ', 'e'],
                  ['ê', 'ề', 'ế', 'ể', 'ễ', 'ệ', 'ee'],
                  ['i', 'ì', 'í', 'ỉ', 'ĩ', 'ị', 'i'],
                  ['o', 'ò', 'ó', 'ỏ', 'õ', 'ọ', 'o'],
                  ['ô', 'ồ', 'ố', 'ổ', 'ỗ', 'ộ', 'oo'],
                  ['ơ', 'ờ', 'ớ', 'ở', 'ỡ', 'ợ', 'ow'],
                  ['u', 'ù', 'ú', 'ủ', 'ũ', 'ụ', 'u'],
                  ['ư', 'ừ', 'ứ', 'ử', 'ữ', 'ự', 'uw'],
                  ['y', 'ỳ', 'ý', 'ỷ', 'ỹ', 'ỵ', 'y']]
bang_ky_tu_dau = ['', 'f', 's', 'r', 'x', 'j']

# %%
nguyen_am_to_ids = {}

for i in range(len(bang_nguyen_am)):
    for j in range(len(bang_nguyen_am[i]) - 1):
        nguyen_am_to_ids[bang_nguyen_am[i][j]] = (i, j)

# %%
def is_valid_vietnam_word(word):
    chars = list(word)
    nguyen_am_index = -1
    for index, char in enumerate(chars):
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x != -1:
            if nguyen_am_index == -1:
                nguyen_am_index = index
            else:
                if index - nguyen_am_index != 1:
                    return False
                nguyen_am_index = index
    return True

# %%
def chuan_hoa_dau_tu_tieng_viet(word):
    if not is_valid_vietnam_word(word):
        return word

    chars = list(word)
    dau_cau = 0
    nguyen_am_index = []
    qu_or_gi = False
    for index, char in enumerate(chars):
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x == -1:
            continue
        elif x == 9:  # check qu
            if index != 0 and chars[index - 1] == 'q':
                chars[index] = 'u'
                qu_or_gi = True
        elif x == 5:  # check gi
            if index != 0 and chars[index - 1] == 'g':
                chars[index] = 'i'
                qu_or_gi = True
        if y != 0:
            dau_cau = y
            chars[index] = bang_nguyen_am[x][0]
        if not qu_or_gi or index != 1:
            nguyen_am_index.append(index)
    if len(nguyen_am_index) < 2:
        if qu_or_gi:
            if len(chars) == 2:
                x, y = nguyen_am_to_ids.get(chars[1])
                chars[1] = bang_nguyen_am[x][dau_cau]
            else:
                x, y = nguyen_am_to_ids.get(chars[2], (-1, -1))
                if x != -1:
                    chars[2] = bang_nguyen_am[x][dau_cau]
                else:
                    chars[1] = bang_nguyen_am[5][dau_cau] if chars[1] == 'i' else bang_nguyen_am[9][dau_cau]
            return ''.join(chars)
        return word

    for index in nguyen_am_index:
        x, y = nguyen_am_to_ids[chars[index]]
        if x == 4 or x == 8:  # ê, ơ
            chars[index] = bang_nguyen_am[x][dau_cau]
            return ''.join(chars)

    if len(nguyen_am_index) == 2:
        if nguyen_am_index[-1] == len(chars) - 1:
            x, y = nguyen_am_to_ids[chars[nguyen_am_index[0]]]
            chars[nguyen_am_index[0]] = bang_nguyen_am[x][dau_cau]
        else:
            x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
            chars[nguyen_am_index[1]] = bang_nguyen_am[x][dau_cau]
    else:
        x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
        chars[nguyen_am_index[1]] = bang_nguyen_am[x][dau_cau]
    return ''.join(chars)

# %%
#Chuyển câu tiếng việt về chuẩn gõ dấu kiểu cũ.
def chuan_hoa_dau_cau_tieng_viet(sentence):
    sentence = sentence.lower()
    words = sentence.split()
    for index, word in enumerate(words):
        cw = re.sub(r'(^\p{P}*)([p{L}.]*\p{L}+)(\p{P}*$)', r'\1/\2/\3', word).split('/')
        if len(cw) == 3:
            cw[1] = chuan_hoa_dau_tu_tieng_viet(cw[1])
        words[index] = ''.join(cw)
    return ' '.join(words)

# %%
#Chuẩn hóa viết tắt
def chuan_hoa_viet_tat_tieng_viet(sentence):
  sentence = re.sub(r'\b[k][s]([a][n]|[ạ][n])?\b', 'khách sạn', sentence)
  sentence = re.sub(r'\b[n][v]([i][e][n]|[i][ê][n])?\b', 'nhân viên', sentence)
  sentence = re.sub(r'\b[d][v]([u]|[ụ])?\b', 'dịch vụ', sentence)
  sentence = re.sub(r'\b[v][i][e][w]\b', 'khung cảnh', sentence)
  sentence = re.sub(r'\b[b][o][o][k]\b', 'đặt', sentence)
  sentence = re.sub(r'\b[g]([d]|[đ])\b', 'gia đình', sentence)
  sentence = sentence.replace('booking', 'đặt phòng')
  sentence = sentence.replace('set up', 'thiết kế')
  sentence = sentence.replace('setup', 'thiết kế')
  sentence = sentence.replace('set', 'bộ')
  sentence = sentence.replace('support', 'hỗ trợ')
  sentence = sentence.replace('check out', 'trả phòng')
  sentence = sentence.replace('checkout', 'trả phòng')
  sentence = sentence.replace('check in', 'nhận phòng')
  sentence = sentence.replace('checkin', 'nhận phòng')
  sentence = sentence.replace('delay', 'trì hoãn')
  sentence = sentence.replace('resort', 'khu nghĩ dưỡng')
  sentence = sentence.replace('service', 'dịch vụ')
  sentence = sentence.replace('menu', 'thực đơn')
  sentence = sentence.replace('upgrade', 'nâng cấp')
  sentence = sentence.replace('take care', 'chăm sóc')
  sentence = sentence.replace('takecare', 'chăm sóc')
  sentence = sentence.replace('thank you', 'cảm ơn')

  sentence = re.sub(r'\b[t][h][a][n][k][s]?\b', 'cảm ơn', sentence)
  sentence = re.sub(r'\b[đ]\b', 'điểm', sentence)
  sentence = re.sub(r'\b([d]|[đ])[c]\b', 'được', sentence)
  sentence = re.sub(r'\b[o][k]\b', 'tốt', sentence)
  sentence = re.sub(r'\b[v][s]\b', 'với', sentence)
  sentence = re.sub(r'\b[k][o]?\b', 'không', sentence)
  sentence = re.sub(r'\b[k][h]\b', 'không', sentence)
  sentence = re.sub(r'\b[n][i][c][e]?\b', 'tuyệt vời', sentence)
  # nma, j, mn, nhah
  return sentence

# %%
# !pip install underthesea

# %%
# BEFORE LABEL
def text_preprocess_before_label(document):
    # chuẩn hóa unicode
    document = convert_unicode(document)
    # chuẩn hóa cách gõ dấu tiếng Việt
    document = chuan_hoa_dau_cau_tieng_viet(document)
    # đưa về lower (chữ thường)
    # document = document.lower()
    # xóa các ký tự không cần thiết
    document = re.sub(r'[&]', 'và', document)
    document = re.sub(r'[^\s\w%!?.,]', ' ', document)
    # xóa khoảng trắng thừa
    document = re.sub(r'\s+', ' ', document).strip()
    # Sửa chính tả, lỗi cú pháp, viết tắt, tiếng anh lẫn vào, không dấu bằng tay trên gg sheet
    document = chuan_hoa_viet_tat_tieng_viet(document)
    return document

# %%
from underthesea import word_tokenize
def text_preprocess(document):
    # chuẩn hóa unicode
    document = convert_unicode(document)
    # chuẩn hóa cách gõ dấu tiếng Việt
    document = chuan_hoa_dau_cau_tieng_viet(document)
    # đưa về lower (chữ thường)
    document = document.lower()
    # xóa các ký tự không cần thiết
    document = re.sub(r'[^\s\w%_]',' ',document)
    # xóa khoảng trắng thừa
    document = re.sub(r'\s+', ' ', document).strip()
    # Sửa chính tả, lỗi cú pháp, viết tắt, tiếng anh lẫn vào, không dấu bằng tay trên gg sheet
    document = chuan_hoa_viet_tat_tieng_viet(document)
    # tách từ
    document = word_tokenize(document, format="text")

    return document

# %%
df_total_new = df_travel_total.copy()

# %%
for i in range(len(df_total_new)):
  df_total_new['Review'][i] = text_preprocess_before_label(df_total_new['Review'][i])
  df_total_new['Review'][i] = re.sub(r'\b[h]\b', 'giờ', df_total_new['Review'][i])

# %%
for i in range(len(df_total_new)):
  df_total_new['Review'][i] = text_preprocess(df_total_new['Review'][i])
  df_total_new['Review'][i] = re.sub(r'\b[h]\b', 'giờ', df_total_new['Review'][i])
# Out:
# <ipython-input-84-9dbce1593e43>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_new['Review'][i] = text_preprocess(df_total_new['Review'][i])
# <ipython-input-84-9dbce1593e43>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_new['Review'][i] = re.sub(r'\b[h]\b', 'giờ', df_total_new['Review'][i])

# %%
df_total_new = df_total_new.drop_duplicates(subset='Review', keep='first')
df_total_new = df_total_new.set_index(np.array(range(df_total_new.shape[0])))

# %%
df_check = df_total_new[df_total_new.Review.str.len() <= 300]
df_check = df_check[df_check.Review.str.len() >= 40]

# %%
df_check
# Out:
#           CustomerName     Address                                 NameHotel  \
# 0            Quang Q.     Quy Nhơn                     Khách sạn Phương Đông
# 1        Thi T. T. T.   Phan Thiết                     Mũi Né Boutique Hotel
# 2           Ekasit W.      Đà Nẵng  Mercure Danang French Village Bana Hills
# 4           Lam M. N.     Vũng Tàu                            Bella VT Hotel
# 6             Ngoc D.      Đà Nẵng           Muong Thanh Grand Da Nang Hotel
# ...                ...         ...                                       ...
# 7842     Nguyen T. N.      Đà Nẵng                     Alibaba Hotel Da Nang
# 7843  Nguyen T. X. Q.       Đà Lạt                       Dalat Wonder Resort
# 7844     Thi T. H. T.       Đà Lạt                       Dalat Wonder Resort
# 7845         Ha T. P.    Nha Trang              Khách sạn Sun City Nha Trang
# 7846     Thi N. T. K.      Đà Nẵng  Mercure Danang French Village Bana Hills
#
# ...

# %%
df_total_new.Review.str.len().value_counts()[350:400]

# %%
df_total_new.shape
# Out:
# (10277, 5)

# %%
df_check[df_check.Ratting < 8].Ratting.value_counts().sum()
# Out:
# 3179

# %%
df_down = df_check[df_check.Ratting < 8]

# %%
df_up = df_check[df_check.Ratting >= 8]

# %%
df_up = df_up[df_up.Review.str.len() >= 60]

# %%
df_final = pd.concat([df_up, df_down])

# %%
df_final = df_final.sample(frac=1).reset_index(drop=True)

# %%
df_final.to_csv('data_pro_travel.csv', index=False, header=True)

# %%
start_date = pd.Timestamp('2015-01-01')
end_date = pd.Timestamp('2023-09-30')

num_days = (end_date - start_date).days + 1
random_dates = pd.to_datetime(np.random.randint(0, num_days, size=len(df_final)), unit='D', origin=start_date)
df_final['Date'] = random_dates

# %%
df_final = df_final.sort_values('Date')
df_final = df_final.set_index(np.array(range(df_final.shape[0])))

# %%
df_final
# Out:
#           CustomerName    Address                        NameHotel  Ratting  \
# 0               Le H.         Huế   Hương Giang Hotel Resort & Spa      6.4
# 1          Ngoc Q. P.    Quy Nhơn                      Ly Ky Hotel      8.8
# 2         Thanh N. T.    Vũng Tàu                   Bella VT Hotel      6.0
# 3     Nguyen H. T. Q.    Vũng Tàu             Nolis Hotel Vung Tau      9.7
# 4           Thi H. N.     Đà Nẵng             Khách sạn Brown Bean      8.7
# ...                ...        ...                              ...      ...
# 6483          Nhan N.    Vũng Tàu  Lan Rung Phuoc Hai Resort & Spa      9.1
# 6484         Le P. A.     Đà Nẵng  Muong Thanh Grand Da Nang Hotel      8.5
# 6485    Dang T. T. V.      Đà Lạt        K Boutique Hotel in Dalat      9.4
# 6486        Duc C. N.   Nha Trang     Mường Thanh Luxury Nha Trang      6.8
# 6487    Tran T. P. A.    Vũng Tàu       Melia Ho Tram Beach Resort      9.7
#
# ...

# %%
df_up = df_total_new[df_total_new.Ratting >= 8]

# %%
# df_total = df_total.sort_values('Date')
# df_total = df_total.set_index(np.array(range(df_total.shape[0])))
# df_total = pd.concat([df_travel_total, df_ivivu_total])

# %%
df_up = df_up.sort_values('Address')
df_up = df_up.set_index(np.array(range(df_up.shape[0])))

# %%
df_up_10 = df_up[df_up.Ratting >9.7]
df_up_9 = df_up[(df_up.Ratting > 9.4) & (df_up.Ratting <= 9.7)]
df_up_85_9 = df_up[(df_up.Ratting > 8.7) & (df_up.Ratting <= 9.4)]
df_up_8 = df_up[df_up.Ratting <= 8.7]

# %%
df_up.Ratting.value_counts()
# Out:
# 9.7     1689
# 8.5     1614
# 9.4      887
# 10.0     779
# 9.1      523
# 8.8      398
# 8.4      122
# 8.7       98
# 9.0       77
# 9.3       56
# 8.3       48
# 9.6       36
# 8.2       32
# 8.6       27
# 8.1       20
# 8.0       10
# 8.9        9
# 9.2        3
# Name: Ratting, dtype: int64

# %%
print(df_up_10.shape)
print(df_up_9.shape)
print(df_up_85_9.shape)
print(df_up_8.shape)
# Out:
# (779, 5)
# (1725, 5)
# (1953, 5)
# (1971, 5)

# %%
df_up_new = pd.concat([df_up_10, df_up_9, df_up_85_9, df_up_8])

# %%
df_up_new
# Out:
#           CustomerName  Address                                   NameHotel  \
# 7              Thi V.       Huế                          Melia Vinpearl Hue
# 8       Tran T. H. V.       Huế                          Hong Thien 1 Hotel
# 15         Pham N. L.       Huế                          Melia Vinpearl Hue
# 31           Thanh H.       Huế           Khách sạn Mường Thanh Holiday Huế
# 38    Nguyen T. T. H.       Huế                       Century Riverside Hue
# ...                ...      ...                                         ...
# 6413        Thi V. N.   Đà Nẵng                          Angel Hotel Danang
# 6414       Hanphan H.   Đà Nẵng                    The Secret Garden Hostel
# 6416  Buidinhthanh B.   Đà Nẵng                         Davue Hotel Da Nang
# 6420   Thanh T. H. N.   Đà Nẵng                       Khách sạn Royal Charm
# 6422           Bui T.   Đà Nẵng  Khu nghỉ dưỡng và Spa Mikazuki Nhật Bản
#
# ...

# %%
df_up_new.to_csv('data_pro_travel_up_8.csv', index=False, header=True)

# %%
df_total_new.to_csv('data_pro_ivivu.csv', index=False, header=True)
