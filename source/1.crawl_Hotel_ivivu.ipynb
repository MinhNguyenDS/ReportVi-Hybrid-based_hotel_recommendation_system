# %%
import pandas as pd
import requests
import numpy as np

# %%
#Id và địa điểm
IdAddress = [[114181, 'Phú Quốc'],
            [114217, 'Đà Lạt'],
            [114213, 'Quy Nhơn'],
            [114198, 'Vũng Tàu'],
            [114184, 'Nha Trang'],
            [114182, 'Đà Nẵng'],
            [114183, 'Phan Thiết'],
            [114186, 'Huế'],
            [114193, 'Hội An'],
            [114183, 'Phan Thiết']]

# %%
def crawl_link(id = 0, name = '_', number = 20):
  """
      id: id của địa điểm
      name: tên địa điểm
      number: số lượng khách sạn muốn có của địa điểm
  """
  regionId = id

  numberHotel = number

  url = 'https://www.ivivu.com/hotelslist?regionId=' + str(regionId) + '&version=2&page=1&pageSize=' + str(numberHotel)

  headers = {
      "Connection": "keep-alive",
      "Host": "www.ivivu.com",
      "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
      "Accept": "application/json, text/plain, '/'",
      "Cookie": "di=14-12-2022; do=15-12-2022; _gcl_au=1.1.780735274.1670233259; _gid=GA1.2.1900749767.1670233259; _fbp=fb.1.1670233259776.484938697; G_ENABLED_IDPS=google; __gads=ID=d9d950196de27a3a-22fe2b6fbfd800ce:T=1670233260:RT=1670233260:S=ALNI_MZvsh1xMhp11HEVfpF67jES-Pljqw; __gpi=UID=00000b8a618e09c1:T=1670233260:RT=1670233260:S=ALNI_MZRUz2rQnn8xOsB8qaFW1pFd3Z7PA; _hjSessionUser_1076641=eyJpZCI6ImJiMTNhNTFhLTdjZTgtNWY3Yi1iMjU5LWQzMGMwMjUyYTc0ZCIsImNyZWF0ZWQiOjE2NzAyMzMyNjAzNTIsImV4aXN0aW5nIjp0cnVlfQ==; _tt_enable_cookie=1; _ttp=345bb69a-cca6-4aa0-9556-d56cdc42444a; HOTLINE=%7B%22Code%22%3A%22HCM%22%2C%22distance%22%3A0%2C%22Hotline%22%3A%2219001870%22%2C%22HotlineDisplay%22%3A%221900%201870%22%2C%22YourIP%22%3A%2214.241.237.198%22%2C%22Msg%22%3A%22from%20ivivu%22%2C%22locationName%22%3A%22H%E1%BB%93%20Ch%C3%AD%20Minh%22%2C%22Time%22%3A%227h30%20%E2%86%92%2021h%22%7D; flagCalendarholidays=true; _hjIncludedInSessionSample=0; _hjSession_1076641=eyJpZCI6IjgwNmU4ZDgzLWIyZTYtNDNkOS04NzkwLWUwNTE1NDgzYWY1NyIsImNyZWF0ZWQiOjE2NzAyNTA5MzQxMjEsImluU2FtcGxlIjpmYWxzZX0=; _hjIncludedInPageviewSample=1; _hjAbsoluteSessionInProgress=0; ASP.NET_SessionId=ooe04pagslct1fe3snzzo3ip; _ga=GA1.1.1272011070.1670233259; _gat=1; _ga_YRG1RN8JP1=GS1.1.1670250933.4.1.1670251319.52.0.0"
  }

  rep_link = requests.post(url, headers = headers)
  HotelName = []
  HotelCode = []
  Point = []
  ReviewCount = []
  for item in rep_link.json()['List']:
      HotelName.append(item['HotelName'])
      HotelCode.append(item['HotelCode'])
      Point.append(item['Point'])
      ReviewCount.append(item['ReviewCount'])

  df_link = pd.DataFrame({'Address': name, 'HotelName':HotelName, 'HotelCode': HotelCode, 'Point':Point, 'ReviewCount':ReviewCount})
  return df_link

# %%
def df_Hotel(address = '_', name = '_', link = '_', countRv = 0):
  """
      address: địa điểm
      name: tên khách sạn
      link: đường dẫn phụ
      countRv: đếm số lượng review
  """
  Address = address
  NameHotel = name

  url = 'https://www.ivivu.com/hotelrequest/morereviews?hotelSlug=' + link + '&total=' + str(countRv) + '&offset=0'

  headers = {
      "Connection": "keep-alive",
      "Host": "www.ivivu.com",
      "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
      "Accept": "text/html, '/'; q=0.01",
      "Cookie": 'HOTLINE=%7B%22Code%22%3A%22HCM%22%2C%22distance%22%3A0%2C%22Hotline%22%3A%2219001870%22%2C%22HotlineDisplay%22%3A%221900%201870%22%2C%22YourIP%22%3A%2214.241.237.198%22%2C%22Msg%22%3A%22from%20ivivu%22%2C%22locationName%22%3A%22H%E1%BB%93%20Ch%C3%AD%20Minh%22%2C%22Time%22%3A%227h30%20%E2%86%92%2021h%22%7D; di=14-12-2022; do=15-12-2022; flagCalendarholidays=true; _gcl_au=1.1.780735274.1670233259; _gid=GA1.2.1900749767.1670233259; _fbp=fb.1.1670233259776.484938697; G_ENABLED_IDPS=google; __gads=ID=d9d950196de27a3a-22fe2b6fbfd800ce:T=1670233260:RT=1670233260:S=ALNI_MZvsh1xMhp11HEVfpF67jES-Pljqw; __gpi=UID=00000b8a618e09c1:T=1670233260:RT=1670233260:S=ALNI_MZRUz2rQnn8xOsB8qaFW1pFd3Z7PA; _hjFirstSeen=1; _hjIncludedInSessionSample=0; _hjSession_1076641=eyJpZCI6IjlkMjk5Nzg5LTY3YmUtNGVjNy1iMjI1LTM3MmIwOWFiZDYyOCIsImNyZWF0ZWQiOjE2NzAyMzMyNjIzOTQsImluU2FtcGxlIjpmYWxzZX0=; _hjIncludedInPageviewSample=1; _hjAbsoluteSessionInProgress=0; _hjSessionUser_1076641=eyJpZCI6ImJiMTNhNTFhLTdjZTgtNWY3Yi1iMjU5LWQzMGMwMjUyYTc0ZCIsImNyZWF0ZWQiOjE2NzAyMzMyNjAzNTIsImV4aXN0aW5nIjp0cnVlfQ==; _tt_enable_cookie=1; _ttp=345bb69a-cca6-4aa0-9556-d56cdc42444a; ASP.NET_SessionId=eyh1nghyymgoynkpr0b40ych; _gat=1; _ga=GA1.1.1272011070.1670233259; _ga_YRG1RN8JP1=GS1.1.1670233258.1.1.1670233352.31.0.0'
  }

  req_data = requests.post(url, headers = headers)

  CustomerName = []
  ReviewPoint = []
  BestFeature = []
  DateStayed = []
  for item in req_data.json()['reviews']:
    if item['BestFeature'] != '':
      CustomerName.append(item['CustomerName'])
      ReviewPoint.append(item['ReviewPoint'])
      BestFeature.append(item['BestFeature'])
      DateStayed.append(item['DateStayed'])

  df_ivivu = pd.DataFrame({'CustomerName':CustomerName, 'Address':Address, 'NameHotel': NameHotel, 'Point': ReviewPoint, 'Review': BestFeature, 'Date': DateStayed})

  return df_ivivu

# %%
for k in range(len(IdAddress)):
  # Chọn số lượng khách sạn tối đa trên 1 location
  max_loc = 500
  df_test = crawl_link(IdAddress[k][0], IdAddress[k][1], max_loc)
  # Chọn phạm vi số lượng cmt của khách sạn (min_; max_)
  min_cmt = 20
  # max_cmt = 500
  # df_link = df_test[(df_test['ReviewCount'] > min_cmt) & (df_test['ReviewCount'] < max_cmt)]
  df_link = df_test[(df_test['ReviewCount'] > min_cmt)]

  df_link = df_link.set_index(np.array(range(df_link.shape[0])))

  # Tạo dataframe cho từng location
  for i in range(len(df_link)):
    # ReviewCount_Craw = df_link['ReviewCount'][i]
    # if ReviewCount_Craw > 100: ReviewCount_Craw = 100
    # df_temp = df_Hotel(df_link['Address'][i], df_link['HotelName'][i], df_link['HotelCode'][i], ReviewCount_Craw)
    df_temp = df_Hotel(df_link['Address'][i], df_link['HotelName'][i], df_link['HotelCode'][i], df_link['ReviewCount'][i])
    if i == 0: df_location = df_temp
    else: df_location = pd.concat([df_location, df_temp])
  df_location = df_location.set_index(np.array(range(df_location.shape[0])))

  # Nối dataframe của tất cả location
  if k == 0: df_total = df_location
  else: df_total = pd.concat([df_total, df_location])

df_total.drop_duplicates(inplace=True)

# %%
df_total.Date = pd.to_datetime(df_total['Date'])
df_total = df_total.sort_values('Date')
df_total = df_total.drop_duplicates(subset='Review', keep='first')
df_total = df_total.set_index(np.array(range(df_total.shape[0])))
# Out:
# <ipython-input-18-1efd7882d130>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_total.Date = pd.to_datetime(df_total['Date'])

# %%
df_total
# Out:
#             CustomerName     Address  \
# 0      Trần Ngọc Tú Oanh      Đà Lạt
# 1            Jonathan W.         Huế
# 2          Ngo Hong Linh      Đà Lạt
# 3            Hà Xuân Lập    Vũng Tàu
# 4              Norwegian      Đà Lạt
# ...                  ...         ...
# 37538                Mai   Nha Trang
# 37539    Trần Thị Lệ Anh     Đà Nẵng
# 37540          Pham Thao  Phan Thiết
# 37541    Dương Quốc Hùng  Phan Thiết
# 37542    Nguyễn Thị Thúy         Huế
#
#                                       NameHotel Point  \
# 0                      Khách sạn Sài Gòn Đà Lạt   8.0
# 1                Vedana Lagoon Resort & Spa Huế  10.0
# 2                 Khách sạn La Sapinette Đà Lạt   6.3
# 3                      Khách sạn Green Vũng Tàu   6.7
# 4                  Khách sạn Mường Thanh Đà Lạt   8.0
# ...                                         ...   ...
# 37538              Khách sạn Majestic Nha Trang   9.0
# 37539                    Khách sạn Gold Đà Nẵng   9.0
# ...

# %%
df_total = df_total[df_total.Review.str.len() >= 50]
df_total = df_total[df_total.Review.str.len() <= 300]
df_total['Review'] = df_total['Review'].str.replace('\n', ' ')
df_total = df_total.set_index(np.array(range(df_total.shape[0])))

# %%
a = df_total.copy()

# %%
a = a[a.Review.str.len() >= 50]
a = a[a.Review.str.len() <= 300]

# %%
a['Review'] = a['Review'].str.replace('\n', ' ')

# %%
a = a.set_index(np.array(range(a.shape[0])))

# %%
for i in range(10):
  print(len(a[a.Address == IdAddress[i][1]]))
# Out:
# 7532
# 9063
# 1353
# 8864
# 4005
# 2965
# 2928
# 417
# 416
# 2928

# %%
a.Point.value_counts()
# Out:
# 10.0    21549
# 8.0      7592
# 9.0      4367
# 9.5      1291
# 6.0      1051
# 7.0       734
# 8.5       319
# 4.0       113
# 7.5       109
# 7.3        66
# 7.7        56
# 2.0        40
# 8.7        40
# 8.3        38
# 6.7        36
# 5.0        29
# 9.3        28
# 6.3        22
# 9.7        20
# 6.5        11
# 5.7         9
# 1.3         4
#             3
# 5.3         3
# 1.0         3
# 4.7         3
# 9.8         2
# 7.8         1
# 7.2         1
# 1.7         1
# 7.6         1
# 8.6         1
# Name: Point, dtype: int64

# %%
df_total.to_csv('data_raw_ivivu_37k.csv', index=False, header=True)

# %%
df_total = pd.read_csv('data_raw_ivivu_37k.csv')

# %%
df_total.dropna(inplace=True)

# %%
df_total = df_total[df_total['CustomerName'].str.contains(' ')]

# %%
df_total = df_total.set_index(np.array(range(df_total.shape[0])))

# %%
import regex as re

uniChars = "àáảãạâầấẩẫậăằắẳẵặèéẻẽẹêềếểễệđìíỉĩịòóỏõọôồốổỗộơờớởỡợùúủũụưừứửữựỳýỷỹỵÀÁẢÃẠÂẦẤẨẪẬĂẰẮẲẴẶÈÉẺẼẸÊỀẾỂỄỆĐÌÍỈĨỊÒÓỎÕỌÔỒỐỔỖỘƠỜỚỞỠỢÙÚỦŨỤƯỪỨỬỮỰỲÝỶỸỴÂĂĐÔƠƯ"
unsignChars = "aaaaaaaaaaaaaaaaaeeeeeeeeeeediiiiiooooooooooooooooouuuuuuuuuuuyyyyyAAAAAAAAAAAAAAAAAEEEEEEEEEEEDIIIOOOOOOOOOOOOOOOOOOOUUUUUUUUUUUYYYYYAADOOU"


def loaddicchar():
    dic = {}
    char1252 = 'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ'.split(
        '|')
    charutf8 = "à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ".split(
        '|')
    for i in range(len(char1252)):
        dic[char1252[i]] = charutf8[i]
    return dic


dicchar = loaddicchar()

# Đưa toàn bộ dữ liệu qua hàm này để chuẩn hóa lại
def convert_unicode(txt):
    return re.sub(
        r'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ',
        lambda x: dicchar[x.group()], txt)

def no_accent_vietnamese(s):
    convert_unicode(s)
    s = re.sub(u'[àáạảãâầấậẩẫăằắặẳẵ]', 'a', s)
    s = re.sub(u'[ÀÁẠẢÃĂẰẮẶẲẴÂẦẤẬẨẪ]', 'A', s)
    s = re.sub(u'[èéẹẹẻẽêềếệểễ]', 'e', s)
    s = re.sub(u'[ÈÉẸẺẼÊỀẾỆỂỄ]', 'E', s)
    s = re.sub(u'[òóọỏõôồốộổỗơờớợởỡ]', 'o', s)
    s = re.sub(u'[ÒÓỌỎÕÔỒỐỘỔỖƠỜỚỢỞỠ]', 'O', s)
    s = re.sub(u'[ìíịỉĩ]', 'i', s)
    s = re.sub(u'[ÌÍỊỈĨ]', 'I', s)
    s = re.sub(u'[ùúụủũưừứựửữ]', 'u', s)
    s = re.sub(u'[ƯỪỨỰỬỮÙÚỤỦŨ]', 'U', s)
    s = re.sub(u'[ỳýỵỷỹ]', 'y', s)
    s = re.sub(u'[ỲÝỴỶỸ]', 'Y', s)
    s = re.sub(u'Đ', 'D', s)
    s = re.sub(u'đ', 'd', s)

    return s

# %%
def fxn(stng):
    lst = stng.split()
    # Xóa các tên khách hàng có chữ Mr. hoặc Ms.
    if (lst[0] == 'Mr.'): lst.remove('Mr.')
    if (lst[0] == 'Ms.'): lst.remove('Ms.')
    oupt = lst[0]
    count = 0

    for i in range(len(lst) - 1):

        oupt += ' ' + lst[i + 1][0].upper() + '.'

    return oupt

# %%
df_total[df_total.Point < 8][:20]

# %%
# Đổ tên user về dạng chung (giống dữ liệu đường link đầu)
for i in range(len(df_total)):
  df_total['CustomerName'][i] = fxn(no_accent_vietnamese(df_total['CustomerName'][i]))
# Out:
# <ipython-input-64-3f08dce5cd2d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total['CustomerName'][i] = fxn(no_accent_vietnamese(df_total['CustomerName'][i]))

# %%
bang_nguyen_am = [['a', 'à', 'á', 'ả', 'ã', 'ạ', 'a'],
                  ['ă', 'ằ', 'ắ', 'ẳ', 'ẵ', 'ặ', 'aw'],
                  ['â', 'ầ', 'ấ', 'ẩ', 'ẫ', 'ậ', 'aa'],
                  ['e', 'è', 'é', 'ẻ', 'ẽ', 'ẹ', 'e'],
                  ['ê', 'ề', 'ế', 'ể', 'ễ', 'ệ', 'ee'],
                  ['i', 'ì', 'í', 'ỉ', 'ĩ', 'ị', 'i'],
                  ['o', 'ò', 'ó', 'ỏ', 'õ', 'ọ', 'o'],
                  ['ô', 'ồ', 'ố', 'ổ', 'ỗ', 'ộ', 'oo'],
                  ['ơ', 'ờ', 'ớ', 'ở', 'ỡ', 'ợ', 'ow'],
                  ['u', 'ù', 'ú', 'ủ', 'ũ', 'ụ', 'u'],
                  ['ư', 'ừ', 'ứ', 'ử', 'ữ', 'ự', 'uw'],
                  ['y', 'ỳ', 'ý', 'ỷ', 'ỹ', 'ỵ', 'y']]
bang_ky_tu_dau = ['', 'f', 's', 'r', 'x', 'j']

# %%
nguyen_am_to_ids = {}

for i in range(len(bang_nguyen_am)):
    for j in range(len(bang_nguyen_am[i]) - 1):
        nguyen_am_to_ids[bang_nguyen_am[i][j]] = (i, j)

# %%
def is_valid_vietnam_word(word):
    chars = list(word)
    nguyen_am_index = -1
    for index, char in enumerate(chars):
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x != -1:
            if nguyen_am_index == -1:
                nguyen_am_index = index
            else:
                if index - nguyen_am_index != 1:
                    return False
                nguyen_am_index = index
    return True

# %%
def chuan_hoa_dau_tu_tieng_viet(word):
    if not is_valid_vietnam_word(word):
        return word

    chars = list(word)
    dau_cau = 0
    nguyen_am_index = []
    qu_or_gi = False
    for index, char in enumerate(chars):
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x == -1:
            continue
        elif x == 9:  # check qu
            if index != 0 and chars[index - 1] == 'q':
                chars[index] = 'u'
                qu_or_gi = True
        elif x == 5:  # check gi
            if index != 0 and chars[index - 1] == 'g':
                chars[index] = 'i'
                qu_or_gi = True
        if y != 0:
            dau_cau = y
            chars[index] = bang_nguyen_am[x][0]
        if not qu_or_gi or index != 1:
            nguyen_am_index.append(index)
    if len(nguyen_am_index) < 2:
        if qu_or_gi:
            if len(chars) == 2:
                x, y = nguyen_am_to_ids.get(chars[1])
                chars[1] = bang_nguyen_am[x][dau_cau]
            else:
                x, y = nguyen_am_to_ids.get(chars[2], (-1, -1))
                if x != -1:
                    chars[2] = bang_nguyen_am[x][dau_cau]
                else:
                    chars[1] = bang_nguyen_am[5][dau_cau] if chars[1] == 'i' else bang_nguyen_am[9][dau_cau]
            return ''.join(chars)
        return word

    for index in nguyen_am_index:
        x, y = nguyen_am_to_ids[chars[index]]
        if x == 4 or x == 8:  # ê, ơ
            chars[index] = bang_nguyen_am[x][dau_cau]
            return ''.join(chars)

    if len(nguyen_am_index) == 2:
        if nguyen_am_index[-1] == len(chars) - 1:
            x, y = nguyen_am_to_ids[chars[nguyen_am_index[0]]]
            chars[nguyen_am_index[0]] = bang_nguyen_am[x][dau_cau]
        else:
            x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
            chars[nguyen_am_index[1]] = bang_nguyen_am[x][dau_cau]
    else:
        x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
        chars[nguyen_am_index[1]] = bang_nguyen_am[x][dau_cau]
    return ''.join(chars)

# %%
#Chuyển câu tiếng việt về chuẩn gõ dấu kiểu cũ.
def chuan_hoa_dau_cau_tieng_viet(sentence):
    sentence = sentence.lower()
    words = sentence.split()
    for index, word in enumerate(words):
        cw = re.sub(r'(^\p{P}*)([p{L}.]*\p{L}+)(\p{P}*$)', r'\1/\2/\3', word).split('/')
        if len(cw) == 3:
            cw[1] = chuan_hoa_dau_tu_tieng_viet(cw[1])
        words[index] = ''.join(cw)
    return ' '.join(words)

# %%
#Chuẩn hóa viết tắt
def chuan_hoa_viet_tat_tieng_viet(sentence):
  sentence = re.sub(r'\b[k][s]([a][n]|[ạ][n])?\b', 'khách sạn', sentence)
  sentence = re.sub(r'\b[n][v]([i][e][n]|[i][ê][n])?\b', 'nhân viên', sentence)
  sentence = re.sub(r'\b[d][v]([u]|[ụ])?\b', 'dịch vụ', sentence)
  sentence = re.sub(r'\b[v][i][e][w]\b', 'khung cảnh', sentence)
  sentence = re.sub(r'\b[b][o][o][k]\b', 'đặt', sentence)
  sentence = re.sub(r'\b[g]([d]|[đ])\b', 'gia đình', sentence)
  sentence = sentence.replace('booking', 'đặt phòng')
  sentence = sentence.replace('set up', 'thiết kế')
  sentence = sentence.replace('setup', 'thiết kế')
  sentence = sentence.replace('set', 'bộ')
  sentence = sentence.replace('support', 'hỗ trợ')
  sentence = sentence.replace('check out', 'trả phòng')
  sentence = sentence.replace('checkout', 'trả phòng')
  sentence = sentence.replace('check in', 'nhận phòng')
  sentence = sentence.replace('checkin', 'nhận phòng')
  sentence = sentence.replace('delay', 'trì hoãn')
  sentence = sentence.replace('resort', 'khu nghĩ dưỡng')
  sentence = sentence.replace('service', 'dịch vụ')
  sentence = sentence.replace('menu', 'thực đơn')
  sentence = sentence.replace('upgrade', 'nâng cấp')
  sentence = sentence.replace('take care', 'chăm sóc')
  sentence = sentence.replace('takecare', 'chăm sóc')
  sentence = sentence.replace('thank you', 'cảm ơn')

  sentence = re.sub(r'\b[t][h][a][n][k][s]?\b', 'cảm ơn', sentence)
  sentence = re.sub(r'\b[đ]\b', 'điểm', sentence)
  sentence = re.sub(r'\b([d]|[đ])[c]\b', 'được', sentence)
  sentence = re.sub(r'\b[o][k]\b', 'tốt', sentence)
  sentence = re.sub(r'\b[v][s]\b', 'với', sentence)
  sentence = re.sub(r'\b[k][o]?\b', 'không', sentence)
  sentence = re.sub(r'\b[k][h]\b', 'không', sentence)
  sentence = re.sub(r'\b[n][i][c][e]?\b', 'tuyệt vời', sentence)
  # nma, j, mn, nhah
  return sentence

# %%
# !pip install underthesea

# %%
document = "This! is^ a sample_text% with & @special characters.❤❤❤"
document = re.sub(r'[&]', 'và', document)
document = re.sub(r'[^\s\w%!?.,]', ' ', document)

print(document)
# Out:
# This! is  a sample_text% with và  special characters.

# %%
# BEFORE LABEL
def text_preprocess_before_label(document):
    # chuẩn hóa unicode
    document = convert_unicode(document)
    # chuẩn hóa cách gõ dấu tiếng Việt
    document = chuan_hoa_dau_cau_tieng_viet(document)
    # đưa về lower (chữ thường)
    # document = document.lower()
    # xóa các ký tự không cần thiết
    document = re.sub(r'[&]', 'và', document)
    document = re.sub(r'[^\s\w%!?.,]', ' ', document)
    # xóa khoảng trắng thừa
    document = re.sub(r'\s+', ' ', document).strip()
    # Sửa chính tả, lỗi cú pháp, viết tắt, tiếng anh lẫn vào, không dấu bằng tay trên gg sheet
    document = chuan_hoa_viet_tat_tieng_viet(document)
    return document

# %%
from underthesea import word_tokenize
def text_preprocess(document):
    # chuẩn hóa unicode
    document = convert_unicode(document)
    # chuẩn hóa cách gõ dấu tiếng Việt
    document = chuan_hoa_dau_cau_tieng_viet(document)
    # đưa về lower (chữ thường)
    document = document.lower()
    # xóa các ký tự không cần thiết
    document = re.sub(r'[^\s\w%_]',' ',document)
    # xóa khoảng trắng thừa
    document = re.sub(r'\s+', ' ', document).strip()
    # Sửa chính tả, lỗi cú pháp, viết tắt, tiếng anh lẫn vào, không dấu bằng tay trên gg sheet
    document = chuan_hoa_viet_tat_tieng_viet(document)
    # tách từ
    document = word_tokenize(document, format="text")

    return document

# %%
df_total_new = df_total.copy()

# %%
for i in range(len(df_total_new)):
  df_total_new['Review'][i] = text_preprocess_before_label(df_total_new['Review'][i])
  df_total_new['Review'][i] = re.sub(r'\b[h]\b', 'giờ', df_total_new['Review'][i])
# Out:
# <ipython-input-103-e30b3d6e2f19>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_new['Review'][i] = text_preprocess_before_label(df_total_new['Review'][i])
# <ipython-input-103-e30b3d6e2f19>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_new['Review'][i] = re.sub(r'\b[h]\b', 'giờ', df_total_new['Review'][i])

# %%
for i in range(len(df_total_new)):
  df_total_new['Review'][i] = text_preprocess(df_total_new['Review'][i])
  df_total_new['Review'][i] = re.sub(r'\b[h]\b', 'giờ', df_total_new['Review'][i])
# Out:
# <ipython-input-84-9dbce1593e43>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_new['Review'][i] = text_preprocess(df_total_new['Review'][i])
# <ipython-input-84-9dbce1593e43>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_new['Review'][i] = re.sub(r'\b[h]\b', 'giờ', df_total_new['Review'][i])

# %%
# df_total_new = df_total_new.drop_duplicates(subset='Review', keep='first')

# %%
df_total_new.Review[23457]
# Out:
# 'nơi nghỉ dưỡng lý tưởng. dịch vụ tốt'

# %%
df_total_new.Review.str.len().value_counts()[350:400]

# %%
df_total_new.shape
# Out:
# (37429, 6)

# %%
df_total_new = df_total_new[df_total_new.Review.str.len() >= 10]
df_total_new = df_total_new[df_total_new.Review.str.len() <= 500]
df_total_new = df_total_new.set_index(np.array(range(df_total_new.shape[0])))

# %%
df_total_new = df_total_new.drop_duplicates(subset='Review', keep='first')

# %%
df_total_new.shape
# Out:
# (36157, 6)

# %%
df_total_new[df_total_new.Point < 8].Point.value_counts().sum()
# Out:
# 2098

# %%
df_total_new[df_total_new.Point < 8].Review[50:100]
# Out:
# 78     nằm ngay trung tâm hồ tràm,nếu muốn lên vũng t...
# 80     khách sạn đẹp lại có nhân viên rất chuyên nghi...
# 81     xung quanh khách sạn không có nhiều hoạt động ...
# 86     rất gần với chợ đà lạt, đi bộ chỉ mất tối đa 1...
# 89     khách sạn tuyệt đẹp,có hồ bơi ngoài trời có má...
# 92     khách sạn hơi xa trung tâm nhưng rất đẹp, phòn...
# 93     khách sạn khá mới, nên phòng sạch sẽ. ăn sáng ...
# 96     khách sạn tiêu chuẩn 3 sao, phòng ốc và nội th...
# 97     phòng ốc đẹp và sạch sẽ, chúng tôi được nâng c...
# 98     khách sạn có phòng đẹp, theo kiến trúc pháp ăn...
# 99     anh vừa đặt khách sạn này cho kỳ nghỉ mát của ...
# 104    vị trí của khách sạn thì đường hơi khó vào, kh...
# 105    khách sạn tương đối tốt , khang trang, hồ bơi ...
# 107    khách sạn đẹp, thuận tiện cho việc đi lại, đồ ...
# 108    khách sạn ở tốt, ăn sáng ngon, gần biển đẹp nh...
# 111    phòng hơi nhỏ, nhân viên phục vụ tận tình, dịc...
# ...

# %%
df_total_new[df_total_new.Point < 8].to_csv('data_pro_ivivu_under_8.csv', index=False, header=True)

# %%
df_up = df_total_new[df_total_new.Point >= 8]

# %%
df_up = df_up.sample(frac=1).reset_index(drop=True)

# %%
# df_total = df_total.sort_values('Date')
# df_total = df_total.set_index(np.array(range(df_total.shape[0])))
# df_total = pd.concat([df_travel_total, df_ivivu_total])

# %%
import pandas as pd

# %%
import numpy as np

# %%
df_up = pd.read_csv('data_pro_ivivu_up_8.csv')

# %%
df_up = pd.read_csv('/content/data_pro_ivivu_up_new.csv')

# %%
df_under = pd.read_csv('/content/data_pro_ivivu_under_8.csv')

# %%
df_final = pd.concat([df_up, df_under])

# %%
df_final = df_final.sort_values('Date')
df_final = df_final.set_index(np.array(range(df_final.shape[0])))

# %%
df_final.to_csv('data_pro_ivivu.csv', index=False, header=True)

# %%
df_up = df_up.sort_values('Address')
df_up = df_up.set_index(np.array(range(df_up.shape[0])))

# %%
df_up_10 = df_up[df_up.Point == 10]
df_up_8_10 = df_up[(df_up.Point > 8) & (df_up.Point < 10)]
df_up_8 = df_up[df_up.Point == 8]

# %%
df_up.Point.value_counts()
# Out:
# 10.0    20840
# 8.0      7297
# 9.0      4278
# 9.5      1268
# 8.5       315
# 8.7        36
# 8.3        35
# 9.3        28
# 9.7        20
# 8.6         1
# 9.8         1
# Name: Point, dtype: int64

# %%
print(df_up_10.shape)
print(df_up_8_10.shape)
print(df_up_8.shape)
# Out:
# (20840, 6)
# (5982, 6)
# (7297, 6)

# %%
df_up_new = pd.concat([df_up_10, df_up_8_10, df_up_8])

# %%
df_up_new
# Out:
#           CustomerName  Address                                  NameHotel  \
# 0          Hoang M. L.      Huế         Khu nghỉ dưỡng Angsana Lăng Cô Huế
# 1      Nguyen T. K. L.      Huế         Khu nghỉ dưỡng Angsana Lăng Cô Huế
# 2         Nguyen Q. P.      Huế            Silk Path Grand Huế Hotel & Spa
# 3            Lam T. H.      Huế         Hương Giang Hotel Resort & Spa Huế
# 4         Nguyen D. L.      Huế         Khu nghỉ dưỡng Angsana Lăng Cô Huế
# ...                ...      ...                                        ...
# 33938      Huynh C. L.  Đà Nẵng                     Khách sạn Gold Đà Nẵng
# 33939       Dang K. M.  Đà Nẵng  Khách sạn Four Points by Sheraton Đà Nẵng
# 33940         Vo Q. T.  Đà Nẵng             Khách sạn Kova Diamond Đà Nẵng
# 33944      Vu B. G. T.  Đà Nẵng             Khách sạn CANVAS Đà Nẵng Beach
# 34118          Song T.  Đà Nẵng                     Khách sạn Gold Đà Nẵng
#
# ...

# %%
df_up_new.to_csv('data_pro_ivivu_up_8_3part.csv', index=False, header=True)

# %%
df_total_new.to_csv('data_pro_ivivu.csv', index=False, header=True)
